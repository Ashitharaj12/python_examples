# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashitharaj12/python_examples/blob/ashitha/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#example program on RNN
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show again")
plt.rcParams["figure.figsize"] = (10, 6)
sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import io
import plotly.express as px

#define dataset
train=pd.read_csv("/content/sample_data/rnn_train/DailyDelhiClimateTrain.csv")
test=pd.read_csv("/content/sample_data/rnn_test/DailyDelhiClimateTest.csv")
train.head()
test.head()
train.describe().style.background_gradient(cmap="reds")
test.describe().style.background_gradient(cmap="reds")
test.info()
train.info()
train.shape
test.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          114 non-null    object
#  1   meantemp      114 non-null    float64
#  2   humidity      114 non-null    float64
#  3   wind_speed    114 non-null    float64
#  4   meanpressure  114 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB
# (114, 5)

# %%
df=pd.concat([train,test])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1576 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1576 non-null   object
#  1   meantemp      1576 non-null   float64
#  2   humidity      1576 non-null   float64
#  3   wind_speed    1576 non-null   float64
#  4   meanpressure  1576 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 73.9+ KB
# (1576, 5)

# %%
df.describe().style.background_gradient(cmap='Blues')
df.isnull().sum()
df.shape
# Out:
# (1576, 5)

# %%
df.shape
df.index=pd.to_datetime(df['date'])

df['year']=df.index.year
df['month']=df.index.month
df.sample()
# Out:
#                   date  meantemp  humidity  wind_speed  meanpressure  year  \
# date
# 2014-08-10  2014-08-10    28.500    89.906       5.225      1002.156  2014
#
#             month
# date
# 2014-08-10      8

# %%
import plotly.graph_objects as go

fig_temp = go.Figure()
fig_temp.add_trace(go.Scatter(
    x=df.index,
    y=df['meantemp'],
    mode='lines',
    line=dict(color='blue', width=2)
))

fig_temp.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_temp = go.Figure()
fig_temp.add_trace(go.Scatter(
    x=df.index,
    y=df['humidity'],
    mode='lines',
    line=dict(color='pink', width=2)
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
